# %% [markdown]
# # 1. Introduction
# NFL is one of the biggest sports in the USA and analytics have a great impact on this sport as a number of plays are picked each game by looking at numbers. This game is about scoring more points than the rival team, to do so you have to get the ball from your field to the rival's endzone so you have to try getting the best out of every chance to move the ball.
# Of course there are different ways to carry the ball to the rival's endzone, you either do it by passing it in the air to a teammate or you can also carry the ball through the ground by running with it, this is something we'll look into it to see what is better.
# In order to analyze the different stats that an NFL game gives us we'll be using the dataset [NFL Box Scores](https://www.kaggle.com/grayengineering425/nfl-box-scores), there are two datasheets in this link and we'll be using the *box_scores.csv* to get our data.
#
# # 2. Explaining the game
# Before we look into our data, why not get familiar with the game of football (or american football for us the europeans)?
# There are two teams competing for victory in a 120 yards (109.7m) long field although it really is 100 yards (91.44m) as 20 yards are the endzones and no plays are seen there, it's just there for scoring.
# Let's dive into a simple list of features of the game:
# -   **Objective:** Get the ball to the rival's endzone
# -   **Game Time:** There are 4 playing windows called quarters that are 15 minutes long each
# -   **How to get to the endzone:** When you are on the attack there are 4 opportunities to travel 10yards with the ball (either by air or by ground), this opportunities are called downs.
# -   **Scoring:** You get 6 points for getting the ball to the endzone (**TOUCHDOWN!**) or 3 points if you score a field goal kick (with the feet, like us europeans!!). You also can kick an extra point or go for 2 points when a touchdown is scored, so the possiblities are: 3,6,7 or 8 points in an attacking play. When you are defending you can score by intercepting a pass or taking the ball away from your rival and getting it to the endzone, that would be anooother **TOUCHDOWN** but if you tackle an attacker on their endzone you will score 2 points.
# -   **Drawing:** If no team is winning by the end of the 4th quarter we go into overtime: another 15 minute quarter where the first team to score a touchdown gets the win, or if no touchdown is scored the win will go to the team that has a greater score by the end of the overtime period. But what if at the end of this 15 extra minutes we still see a draw? The game ends with a draw at pro level while in college you could get a 10 quarter game because someone has to win.
#
# <div style="text-align:center" markdown="1">
#    <img src="https://i.giphy.com/media/xUPGcB5L0TIfLrDH8c/giphy.webp">
# </div>
#
# # 3. Dependencies
# Let's talk about the libraries and files that you will need to run this notebook.
# -  **OS and Pathlib**: necessary to get our data file.
# -  **Pandas**: all data and matrix operations, without it we will be very limited.
# -  **Sklearn**: helpful to split the data and use our model.
# -  **Seaborn**: will be used to plot the data.
# -  **ingest_data.py**: in this file there are the read data functions
# -  **generate_features.py**: file that gets the data from the previous file and creates the desired features, this dataset needed a lot of cleaning as there are tons of features that have types that cannot be used.

# %%
import os
import sys
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
from pathlib import Path
module_path = os.path.abspath(os.path.join('..'))
sys.path.append(module_path+"\\src")

import pandas as pd
import sklearn as sk

from sklearn import svm

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,f1_score, recall_score, roc_curve, auc
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.preprocessing import label_binarize

import seaborn as sns
import matplotlib.pyplot as plt


from time import time

import ingest_data as id
import generate_features as gf
# Out:
# C:\Users\PCCOM\Documents\kaggle_apc\kaggle-apc2122\data\

# %% [markdown]
# # 4. Let's look at our data
# The first thing we have to do when looking at a problem is to understand the data, if you know what you are talking about it will provide further knowledge or if you don't have a clue about it then you will get a baseline and understand how the data is related. In this case we are going to take a look into the base data without cleaning it and its types.

# %%
games = id.read_data()
print('Total entrances:', games.shape[0], '.')
print('Total fields for each entrance:', games.shape[1], '.')
# Out:
# Total entrances: 4328 .
# Total fields for each entrance: 57 .

# %% [markdown]
# We have recorded 4328 game from 2002 to 2016, that difference in years is to account for the possiblity that a team has gotten pretty good over a certain amount of time which would balance the data towards their end as road upsets tend to be harder in the NFL, we have 57 types of data from these games so the next step is to dive into this recorded data and see what we can do to make it better for predictions.

# %%
pd.set_option('display.max_columns', None)
games.head(5)
# Out:
#                 date       visitor          home  visitor_score  home_score  \
# 0  September 7, 2014     Cleveland    Pittsburgh             27          30
# 1  September 7, 2014  Jacksonville  Philadelphia             17          34
# 2  September 4, 2014     Green Bay       Seattle             16          36
# 3  September 7, 2014     Minnesota     St. Louis             34           6
# 4  September 7, 2014    Cincinnati     Baltimore             23          16
#
#    visitor_first_downs  visitor_rushing_first_downs  \
# 0                   23                            9
# 1                   18                            2
# 2                   19                            4
# 3                   18                            6
# 4                   16                            4
#
#    visitor_passing_first_downs  visitor_penalties  visitor_net_yards  \
# 0                           11                  3                389
# ...

# %% [markdown]
# Before talking about the data let's establish that when you read y_zzzzz_jjjj that "y" will either be home or visitor.
# - y_net_yards_x where x can be passing or rushing and y is home or visitor: yards made by "y" team after taking away the penalty, sacks and safety yards.
# - y_passing_splits: when we find a column that talks about splits it gives us information on the amount of passes a team completed or failed, or sacks-yards_per_sack or a completed-tried of FG and other stopped plays.
# There are a lot of columns that we have to refactor or just delete because they don't give us relevant information like the "Date" and teams, NFL teams can change a lot from one season to another and it has not much sense to keep it, we also have to change those "split" columns we talked earlier as they don't provide clear useful data.
# This is where "generate_features.py" comes handy because it transforms the data and returns a clean dataset that can be used to get correlations.
#
# First step before returning our dataset is to check if there's null values and delete them, this is done in the same function as the feature generation and it will print the size of the sanitized dataset.
# Also in the generate features function we already prune some data that doesn't have that much of data so it won't have major correlation to the final result in addition to change some data from String type to int or float for example the FG Splits that originally are 1-3 (1 made out of 3) now look like 33 as percentages give us better info in this case.
# Generate features also creates the objective variable "results" by looking at the home and away scores and it can have 3 outcomes:
# - 1: Home team win
# - 2: Away team win
# - 3: Tie, this is highly unusual

# %%
data = gf.generate_features()
pd.set_option('display.max_columns', None)
data.head(5)
# Out:
# Total entrances after dropping null values:  4328 .
#    results  Home ToP  Away ToP  home Score  away Score  Home #Plays  \
# 0        1    1947.0    1653.0          30          27           67
# 1        1    1846.0    1754.0          34          17           82
# 2        1    2000.0    1600.0          36          16           66
# 3        2    1903.0    1697.0           6          34           63
# 4        2    1770.0    1830.0          16          23           85
#
#    Away #Plays  Home 1st  Away 1st  Home 1st P  Home 1st R  Away 1st P  \
# 0           64        24        23          16           6          11
# 1           70        24        18          14           7          14
# 2           57        25        19           8          13          13
# 3           57        15        18          10           4          10
# 4           64        26        16          16           8          11
#
#    Away 1st R  Home avg gain  Away avg gain  Home Net Y  Home Net P  \
# ...

# %% [markdown]
# Happily there were no null values in the dataset so we can continue with our data exploration, in the next cell we'll see the results of the describe function to see the information of each attribute.

# %%
data.describe()
# Out:
#            results     Home ToP     Away ToP   home Score   away Score  \
# count  4328.000000  4328.000000  4328.000000  4328.000000  4328.000000
# mean      1.430453  1831.425601  1795.512939    23.161969    20.608364
# std       0.498453   274.126025   277.831744    10.362590    10.039708
# min       1.000000   885.000000   893.000000     0.000000     0.000000
# 25%       1.000000  1647.000000  1603.000000    16.000000    13.000000
# 50%       1.000000  1831.000000  1792.000000    23.000000    20.000000
# 75%       2.000000  2017.000000  1981.000000    30.000000    27.000000
# max       3.000000  2781.000000  2828.000000    62.000000    59.000000
#
#        Home #Plays  Away #Plays     Home 1st     Away 1st   Home 1st P  \
# count  4328.000000  4328.000000  4328.000000  4328.000000  4328.000000
# mean     63.654575    62.925601    19.610213    18.604898    11.529113
# std       8.374063     8.593751     4.948859     4.992492     3.929243
# ...

# %%
plt.figure()
plt.hist(data['results'])
# Out:
# (array([2472.,    0.,    0.,    0.,    0., 1849.,    0.,    0.,    0.,
#            7.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# There's a lot of deviation in our data, I believe this will make the predictions harder but there's another step we need to do in refining our data and it is to check the columns that have a correlation with our objective variable which is result. Also worth noting the dataset doesn't feel too unbalanced except for the ties that are almost inexistant.
# To do this we will apply a filter with the **corr** function.

# %%
correlation = data.corr()['results'].to_frame().T
plt.subplots(figsize=(20,1))
sns.heatmap(correlation)
plt.show()

# %% [markdown]
# It is surprising that the Home team stats are the ones with less correlation with the result of the game, knowing that and also seeing that there's quite a low correlation with other stats I'll proceed to apply a threshold to further inspect the data.

# %%
thresh = 0.3
attr = list(filter(lambda x: abs(float(correlation[x])) > thresh, data.columns))
print('Total of useful attributes:', len(attr), '.')
for el in attr:
    print(el)
#results will appear in this list but of course it won't be there in the test data
data = data[attr]
#sns.pairplot(data, hue="results")
# Out:
# Total of useful attributes: 10 .
# results
# Home ToP
# Away ToP
# home Score
# away Score
# Home 1st R
# Away 1st R
# Home Net R
# Away Net Y
# Away Net R

# %% [markdown]
# # 5. It's time to predict some games
# My initial thoughts with this dataset was to see if the weather had an impact in the games with the help of a weather dataset, I couldn't do it as the weather dataset didn't have the same games as the one with the stats so I couldn't check if it had an impact, it was a shame so I focused more in the offensive stats for both teams as it looks that offense stats are better for prediction rather than defensive even though low offensive production is often result of a great defense.
#
# **5.1 Model Selection**
# First things first, we need to talk about which models we are using to determine the results of a game, my intention is to use random forests, SVMs and KNN and then compare the three models to decide which one is the better of them all.
# SVMs might be an intersting choice with the usage of kernels so that's the first model we'll be trying.
#
# **5.2 Data split**
# We'll be using cross-validation to train and test our data, specifically we are going to see the use of **Stratified K-Fold** to have a more balanced train and test sets. For the train data I'm dropping the objective variable and the "home Score", the reason behind this is because with this variable what the model will do is just check if homeScore <= awayScore and get the results, I've tried that and got a 100% accuracy but I think it is more challenging to try the models without that easy of a solution.

# %%
X = data.drop(labels=['results', 'home Score'], axis=1)
Y = data['results']
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.8, random_state=42, stratify=Y)

# %% [markdown]
# **5.3 Metrics**
# The three metrics use to compare the results will be *accuracy, F1 and recall* which I believe will give a good information on the perfomance of our models.
# Let's imagine a scenario to understand our metrics a bit more. We work for a marketing corporation that wants metrics on their advertisments, the three selected metrics would work like this.
# *Accuracy*: % of times our model is right on whether a client wants to buy a product or not.
# *Recall*: % of clients we are capable of correctly detect that would be interested in an offer.
# *F1*: It would compare the precision and recall, that is how many times we were correct on a client wanting to buy our products *precision* and the *recall*.
# For me I think that recall will be the most significant of the three

# %% [markdown]
# **5.4** SVM

# %% [markdown]
# **SVM**
# *Kernel Poly*

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.85, random_state=42, stratify=Y)

t0 = time()
poly = sk.svm.SVC(decision_function_shape='ovo',kernel='poly',degree=6, C=10).fit(x_train, y_train)
y_pred = poly.predict(x_test)
acc = sk.metrics.accuracy_score(y_test, y_pred)
f1 = sk.metrics.f1_score(y_test, y_pred, average='weighted')
mr = sk.metrics.recall_score(y_test, y_pred, average='macro')


print("Accuracy:",acc)
print("F1:",f1)
print("Recall:", mr)
print("Time in seconds:",time()-t0)

plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=Y, s=50, cmap='autumn')
plt.scatter(poly.support_vectors_[:,0],poly.support_vectors_[:,1])
# Out:
# Accuracy: 0.8076923076923077
# F1: 0.8074633682947153
# Recall: 0.8681539943247558
# Time in seconds: 0.35788607597351074

# %% [markdown]
# This kernel is giving really good overall results with a great speed, I'm surprised with the 86ish% recall because it is higher than the accuracy and the F1, also it doesn't make much sense as we'll see in the next code cell.
# Since it is so quick we can check the best value for our train_test division.

# %%
splits = [10,20,30,40,50,60,70,80,85,90,95]
res_acc_t = []
res_f1_t = []
res_rec_t = []
for t_split in splits:
    x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=t_split, random_state=42, stratify=Y)
    poly = sk.svm.SVC(decision_function_shape='ovo',kernel='poly',degree=6, C=10).fit(x_train, y_train)
    y_pred = poly.predict(x_test)
    acc = sk.metrics.accuracy_score(y_test, y_pred)
    f1 = sk.metrics.f1_score(y_test, y_pred, average='weighted')
    mr = sk.metrics.recall_score(y_test, y_pred, average='macro')
    res_acc_t.append(acc)
    res_f1_t.append(f1)
    res_rec_t.append(mr)


max_v = max(res_rec_t)
max_v2 = max(res_acc_t)
max_v3 = max(res_f1_t)
max_pos = res_rec_t.index(max_v)

plt.xlabel(splits)
plt.title("Comparison")
plt.plot(res_rec_t, label="Recall")
plt.plot(res_acc_t, label="Accuracy") 
plt.plot(res_f1_t, label="F1")
plt.legend(["Recall", "Accuracy", "F1"])

print("Best recall value: ", round(max_v * 100, 3),"%", "with", splits[max_pos],"% train-test split.")
print("Best accuracy value: ", round(max_v2 * 100, 3),"%", "with", splits[max_pos],"% train-test split.")
print("Best F1 value: ", round(max_v3 * 100, 3),"%", "with", splits[max_pos],"% train-test split.")
# Out:
# Best recall value:  47.825 % with 85 % train-test split.
# Best accuracy value:  72.519 % with 85 % train-test split.
# Best F1 value:  72.355 % with 85 % train-test split.

# %% [markdown]
# Before trying another kernel I want to remark that this recall below the 50% makes much more sense than the 86ish% that was shown in the cells above, although it is still strange that when ran 1 time it gave that result but when ran after another SVM it gave a different result.

# %%
t0 = time()
rbf = sk.svm.SVC(decision_function_shape='ovo',kernel='rbf',degree=6, C=10).fit(x_train, y_train)
y_pred = rbf.predict(x_test)
acc = sk.metrics.accuracy_score(y_test, y_pred)
f1 = sk.metrics.f1_score(y_test, y_pred, average='weighted')
mr = sk.metrics.recall_score(y_test, y_pred, average='macro')
print("Accuracy:",acc)
print("F1:",f1)
print("Recall:", mr)
print("Time in seconds:",time()-t0)

plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=Y, s=50, cmap='autumn')
plt.scatter(rbf.support_vectors_[:,0],rbf.support_vectors_[:,1])
# Out:
# Accuracy: 0.6895818568391212
# F1: 0.6874123380175388
# Recall: 0.45328149742223395
# Time in seconds: 0.04098677635192871

# %%
splits = [10,20,30,40,50,60,70,80,85,90,95]
res_acc_t = []
res_f1_t = []
res_rec_t = []
for t_split in splits:
    x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=t_split, random_state=42, stratify=Y)
    rbf = sk.svm.SVC(decision_function_shape='ovo',kernel='rbf',degree=6, C=10).fit(x_train, y_train)
    y_pred = rbf.predict(x_test)
    acc = sk.metrics.accuracy_score(y_test, y_pred)
    f1 = sk.metrics.f1_score(y_test, y_pred, average='weighted')
    mr = sk.metrics.recall_score(y_test, y_pred, average='macro')
    res_acc_t.append(acc)
    res_f1_t.append(f1)
    res_rec_t.append(mr)


max_v = max(res_rec_t)
max_v2 = max(res_acc_t)
max_v3 = max(res_f1_t)
max_pos = res_rec_t.index(max_v)

plt.xlabel(splits)
plt.title("Comparison")
plt.plot(res_rec_t, label="Recall")
plt.plot(res_acc_t, label="Accuracy") 
plt.plot(res_f1_t, label="F1")
plt.legend(["Recall", "Accuracy", "F1"])

print("Best recall value: ", round(max_v * 100, 3),"%", "with", splits[max_pos],"% train-test split.")
print("Best accuracy value: ", round(max_v2 * 100, 3),"%", "with", splits[max_pos],"% train-test split.")
print("Best F1 value: ", round(max_v3 * 100, 3),"%", "with", splits[max_pos],"% train-test split.")
# Out:
# Best recall value:  45.408 % with 90 % train-test split.
# Best accuracy value:  69.385 % with 90 % train-test split.
# Best F1 value:  68.867 % with 90 % train-test split.

# %% [markdown]
# Worse results, let's try a linear kernel and hope for the best of the three.

# %%
'''t0 = time()
linear = sk.svm.SVC(decision_function_shape='ovo',kernel='linear',degree=6, C=10, probability=True).fit(x_train, y_train)
y_pred = linear.predict(x_test)
acc = sk.metrics.accuracy_score(y_test, y_pred)
f1 = sk.metrics.f1_score(y_test, y_pred, average='weighted')
mr = sk.metrics.recall_score(y_test, y_pred, average='macro')
print("Accuracy:",acc)
print("F1:",f1)
print("Recall:", mr)
print("Time in seconds:",time()-t0)

plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=Y, s=50, cmap='autumn')
plt.scatter(linear.support_vectors_[:,0],linear.support_vectors_[:,1])

'''
# Out:
# 't0 = time()\nlinear = sk.svm.SVC(decision_function_shape=\'ovo\',kernel=\'linear\',degree=6, C=10, probability=True).fit(x_train, y_train)\ny_pred = linear.predict(x_test)\nacc = sk.metrics.accuracy_score(y_test, y_pred)\nf1 = sk.metrics.f1_score(y_test, y_pred, average=\'weighted\')\nmr = sk.metrics.recall_score(y_test, y_pred, average=\'macro\')\nprint("Accuracy:",acc)\nprint("F1:",f1)\nprint("Recall:", mr)\nprint("Time in seconds:",time()-t0)\n\nplt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=Y, s=50, cmap=\'autumn\')\nplt.scatter(linear.support_vectors_[:,0],linear.support_vectors_[:,1])\n\n'

# %% [markdown]
# The linear kernel doesn't work, it blocks the environment from running, I believe this is because it is not capable to find a separation between the data, that happens with the drop of the "home Score" in the training set so I believe that the model was separating by score and nothing more when it had both scores in the train dataset, that was of course giving amazing results but it didn't made sense to have both scores for prediction.
# To sum up the SVMs I'd say they have produced far better results than expected because when we saw the data correlation I didn't expect to get results better than 50% to 60% and although the accuracy and F1 metrics present such great results I'd like to have a better recall.
# Next step is to try another model.

# %% [markdown]
# **5.5 Random Forests**

# %%
t0 = time()
n_estim = [5,10,20,50,75,100,150,300,500, 1000]
res_acc = []
res_F1 = []
res_rec = []

for est in n_estim:
    random_forest = RandomForestClassifier(n_estimators=est,max_depth=50, max_features=0.6, random_state=42)
    random_forest.fit(x_train,y_train)
    y_pred = random_forest.predict(x_test)
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')
    mr = recall_score(y_test, y_pred, average='macro')
    res_acc.append(acc)
    res_F1.append(f1)
    res_rec.append(mr)
print("Time spent: ",time()-t0)

max_v = max(res_rec)
max_pos = res_rec.index(max_v)
acc_max = res_acc[max_pos]
f1_max = res_F1[max_pos]

plt.xlabel(n_estim)
plt.title("Comparison")
plt.plot(res_rec, label="Recall")
plt.plot(res_acc, label="Accuracy") 
plt.plot(res_F1, label="F1")
plt.legend(["Recall", "Accuracy", "F1"])

print("Best recall value: ", round(max_v * 100, 3),"%", "with", n_estim[max_pos], "estimators.")
print("Best accuracy value: ", round(acc_max * 100, 3),"%")
print("Best F1 value: ", round(f1_max * 100, 3),"%")
# Out:
# Time spent:  2.749124050140381
# Best recall value:  51.46 % with 300 estimators.
# Best accuracy value:  77.864 %
# Best F1 value:  77.714 %

# %% [markdown]
# Accuracy and F1 are extremely close, let's zoom in.

# %%
plt.xlabel(n_estim)
plt.title("Comparison")
plt.plot(res_acc, label="Accuracy") 
plt.plot(res_F1, label="F1")
plt.legend(["Accuracy", "F1"])

# %% [markdown]
# **5.6 KNN**

# %%
t0=time()

neig = [1,2,3,4,5,10,15,25,50,75,90]

res_acc = []
res_F1 = []
res_rec = []

for el in neig:
    knn_ = KNeighborsClassifier(n_neighbors=el)
    knn_.fit(x_train,y_train)
    y_pred = knn_.predict(x_test)
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')
    mr = recall_score(y_test, y_pred, average='macro')
    res_acc.append(acc)
    res_F1.append(f1)
    res_rec.append(mr)
print("Time spent: ",time()-t0)

max_v = max(res_rec)
max_pos = res_rec.index(max_v)
acc_max = res_acc[max_pos]
f1_max = res_F1[max_pos]

plt.xlabel(neig)
plt.title("Comparison")
plt.plot(res_rec, label="Recall")
plt.plot(res_acc, label="Accuracy") 
plt.plot(res_F1, label="F1")
plt.legend(["Recall", "Accuracy", "F1"])
print("Best recall value: ", round(max_v * 100, 3),"%", "with", neig[max_pos], "n_neighbors.")
print("Best accuracy value: ", round(acc_max * 100, 3),"%")
print("Best F1 value: ", round(f1_max * 100, 3),"%")
# Out:
# Time spent:  1.1526334285736084
# Best recall value:  45.726 % with 15 n_neighbors.
# Best accuracy value:  69.242 %
# Best F1 value:  69.146 %

# %% [markdown]
# KNN is the one that produced the worst results and it makes a lot of sense as the data looked that it didn't have a lot of separation between information.
# Now let's move onto the final analysis before our conclusions. We'll be looking into the confusion matrix of our models and the ROC curves as it'll give us a good understanding of the results.

# %%
#for the SVMs I take the best perfoming kernel which is the linear one, for the other models I've already determined what parameter 
#gave us the better results
knn_ = KNeighborsClassifier(n_neighbors=15)
knn_.fit(x_train,y_train)
knn_pred = knn_.predict(x_test)

random_forest = RandomForestClassifier(n_estimators=est,max_depth=75, max_features=0.6, random_state=42)
random_forest.fit(x_train,y_train)
random_pred = random_forest.predict(x_test)

poly = svm.SVC(decision_function_shape='ovo',kernel='poly',degree=6, C=10, probability=True).fit(x_train, y_train)
poly_pred = poly.predict(x_test)

titles_options = [("SVM Kernel Polynomial", poly),
                  ("Random Forest", random_forest),
                  ("KNN", knn_)]
for title, classifier in titles_options:
    disp = plot_confusion_matrix(classifier, x_test, y_test,
                                 cmap=plt.cm.Greens,
                                 normalize='true')
    disp.ax_.set_title(title)
    print(disp.confusion_matrix)
# Out:
# [[0.7535153  0.2464847  0.        ]
#  [0.34070796 0.65929204 0.        ]
#  [1.         0.         0.        ]]
# [[0.82837055 0.17162945 0.        ]
#  [0.28484513 0.71515487 0.        ]
#  [0.85714286 0.14285714 0.        ]]
# [[0.73904053 0.26095947 0.        ]
#  [0.36725664 0.63274336 0.        ]
#  [0.71428571 0.28571429 0.        ]]

# %%
titles_options = [("SVM Kernel Polynomial", poly_pred),
                  ("Random Forest", random_pred),
                  ("KNN", knn_pred)]
print('-----------------')
for title, pred in titles_options:
    print(title)
    print(classification_report(y_test, pred, target_names=["1", "2", "3"]))
    print('-----------------')
# Out:
# -----------------
# SVM Kernel Polynomial
#               precision    recall  f1-score   support
#
#            1       0.75      0.75      0.75      2418
#            2       0.67      0.66      0.66      1808
#            3       0.00      0.00      0.00         7
#
#     accuracy                           0.71      4233
#    macro avg       0.47      0.47      0.47      4233
# weighted avg       0.71      0.71      0.71      4233
#
# -----------------
# Random Forest
#               precision    recall  f1-score   support
#
#            1       0.79      0.83      0.81      2418
#            2       0.76      0.72      0.74      1808
#            3       0.00      0.00      0.00         7
#
#     accuracy                           0.78      4233
#    macro avg       0.52      0.51      0.52      4233
# weighted avg       0.78      0.78      0.78      4233
#
# -----------------
# KNN
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# Above you can see the report, it's just the confusion matrix in text so you can see it the way you prefer.
# Let's create the last of our visuals before talking about the conclusions, it will be the ROC Curves to see how our model is learning.

# %%
x_train, x_test, y_train, y_test=train_test_split(X, Y, test_size=0.20, random_state=42)

#SVM KERNEL POLY
ns_probs = [0 for _ in range(len(y_test))]
# predict probabilities
lr_probs = poly.predict_proba(x_test)
# keep probabilities for the positive outcome only
y_train = label_binarize(y_train, classes=[1, 2])
y_test = label_binarize(y_test, classes=[1, 2])
n_classes = y_test.shape[1]


NSPFR=dict() 
NSTPR=dict()
LRFPR=dict()
LRTPR=dict()

for i in range(n_classes):
    NSPFR[i], NSTPR[i], _ = roc_curve(y_test[:,i], ns_probs)
    LRFPR[i], LRTPR[i], _ = roc_curve(y_test[:,i], lr_probs[:, i])
    plt.plot(LRFPR[i], LRTPR[i], marker='.', label=i)
    
print('SVM KERNEL POLY')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend(title='Classes')
# show the plot
plt.title(label='Roc curve')
plt.show()


#RANDOM FOREST
ns_probs = [0 for _ in range(len(y_test))]
# predict probabilities
lr_probs = random_forest.predict_proba(x_test)
# keep probabilities for the positive outcome only
y_train = label_binarize(y_train, classes=[1, 2])
y_test = label_binarize(y_test, classes=[1, 2])
n_classes = y_test.shape[1]


NSPFR=dict() 
NSTPR=dict()
LRFPR=dict()
LRTPR=dict()

for i in range(n_classes):
    NSPFR[i], NSTPR[i], _ = roc_curve(y_test[:,i], ns_probs)
    LRFPR[i], LRTPR[i], _ = roc_curve(y_test[:,i], lr_probs[:, i])
    plt.plot(LRFPR[i], LRTPR[i], marker='.', label=i)
    

print('Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend(title='Classes')
# show the plot
plt.title(label='Roc curve')
plt.show()

#KNN
ns_probs = [0 for _ in range(len(y_test))]
# predict probabilities
lr_probs = knn_.predict_proba(x_test)
# keep probabilities for the positive outcome only
y_train = label_binarize(y_train, classes=[1, 2])
y_test = label_binarize(y_test, classes=[1, 2])
n_classes = y_test.shape[1]

NSPFR = dict() 
NSTPR = dict()
LRFPR = dict()
LRTPR = dict()
NSAUC = dict()
LRAUC = dict()

for i in range(n_classes):
    NSPFR[i], NSTPR[i], _ = roc_curve(y_test[:,i], ns_probs)
    NSAUC[i] = auc(NSTPR[i], NSPFR[i])
    LRFPR[i], LRTPR[i], _ = roc_curve(y_test[:,i], lr_probs[:, i])
    LRAUC[i] = auc(LRTPR[i], LRFPR[i])

    plt.plot(LRFPR[i], LRTPR[i], marker='.', label=i)
    
print(NSAUC, LRAUC)
print('KNN')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend(title='Classes')
# show the plot
plt.title(label='Roc curve')
plt.show()
# Out:
# SVM KERNEL POLY
# Random Forest
# {0: 0.5, 1: 0.5} {0: 0.21862137420228409, 1: 0.21776128112033197}
# KNN

# %% [markdown]
# # 6. Conclusions
#
# The first thing that comes to mind with this project is that the results have been far better than what I expected them to be, my thoughts were that the results would be under 70% because of the size of the dataset and let's face it because of the difficulty of predicting a score in sports and the span of time that the data was recorded.
#
# *Happy thoughts*:
# -   Good accuracy and F1 scores!
# -   Can predict a lot of games
# -   Doesn't need a lot of attributes
#
# *Unhappy thoughts*:
# -   Recall was under 50% a lot of times...
# -   Home team performance almost doesn't matter
# -   Ties are too rare
#
# I'm happy with the work done and this has a lot of potential, it could be enhanced to try and predict a win by matchups or try and find a good weather dataset to predict games based on weather.
